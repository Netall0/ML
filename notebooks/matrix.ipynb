# %%
import numpy as np

# %%
A = np.array([[1,2,3],[4,5,6]])
B = np.array([[2,1,1],[2,2,2]])

# %%
A
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
B
# Out:
# array([[2, 1, 1],
#        [2, 2, 2]])

# %%
A-B
# Out:
# array([[-1,  1,  2],
#        [ 2,  3,  4]])

# %% [markdown]
# # multiplication

# %%
X = np.random.randn(50000, 4)

W = np.random.randn(4,1)

Z = np.dot(X, W)
print(Z.shape)
# Out:
# (50000, 1)
